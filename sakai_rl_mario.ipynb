# %%
# 200442066 坂井泰吾
import torch
from torch import nn
from torchvision import transforms as T
from PIL import Image
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from pathlib import Path
from collections import deque
import random, datetime, os, copy
import time
from pyvirtualdisplay import Display

# Gymは、Open AIのRL用ツールキットです
import gym
from gym.spaces import Box  # 連続値の状態空間定義用
from gym.wrappers import FrameStack

# OpenAI Gym用に使うNES エミュレーター
from nes_py.wrappers import JoypadSpace
#OpenAI Gymのスーパー・マリオ・ブラザーズの環境
import gym_super_mario_bros

# stage 選択
stage = "3-4"
selected_env = "SuperMarioBros-" + stage + "-v3"
env = gym_super_mario_bros.make(selected_env)

from gym_super_mario_bros.actions import SIMPLE_MOVEMENT
# actions for very simple movement
# SIMPLE_MOVEMENT = [
#     ['NOOP'],
#     ['right'],
#     ['right', 'A'],
#     ['right', 'B'],
#     ['right', 'A', 'B'],
#     ['A'],
#     ['left'],
# ]
env = JoypadSpace(env, SIMPLE_MOVEMENT)

#再現性を保つためにseedを固定
seed = 15
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
env.action_space.seed(seed)

# 表示テスト
env.reset()
next_state, reward, done, info = env.step(action=0)
print(f"{next_state.shape},\n {reward},\n {done},\n {info}") # f文字列（フォーマット文字列）
    # [3,240, 256]という配列はそれぞれ、画面の[チャネル数, 高さ、幅]
plt.figure(figsize=(5,5))
plt.axis=('off')
plt.imshow(next_state)
# Out:
# (240, 256, 3),
#  0.0,
#  False,
#  {'coins': 0, 'flag_get': False, 'life': 2, 'score': 0, 'stage': 4, 'status': 'small', 'time': 300, 'world': 3, 'x_pos': 40, 'x_pos_screen': 40, 'y_pos': 175}

# %%
# ラッパーはエージェントにデータを渡す前にデータを前処理


# 状態データサイズ縮小 
# この処理をすると、状態サイズ[1, 240, 256]

class GrayScaleObservation(gym.ObservationWrapper):
    def __init__(self, env):
        super().__init__(env)
        obs_shape = self.observation_space.shape[:2]  # =(240,256)
        self.observation_space=Box(low=0,high=255,shape=obs_shape,dtype=np.uint8) #状態空間定義

    def permute_orientation(self, observation):
        # [H, W, C] arrayを[C, H, W] tensorに変換
        observation = np.transpose(observation, (2, 0, 1))
        observation = torch.tensor(observation.copy(), dtype=torch.float)
        return observation

    def observation(self, observation):
        observation = self.permute_orientation(observation)
        transform = T.Grayscale()
        observation = transform(observation)
        return observation

# 各observationを正方形の画像にダウンサンプリング
# この処理を適用すると、状態のサイズは[1, 84, 84]

class ResizeObservation(gym.ObservationWrapper):
    def __init__(self, env, shape):
        super().__init__(env)
        if isinstance(shape, int):    # shapeがintならTrue
            self.shape = (shape, shape)
        else:
            self.shape = tuple(shape)

        obs_shape = self.shape + self.observation_space.shape[2:] # カラーチャンネルがあったら付け加える．タプルの'+'は結合．
        self.observation_space = Box(low=0, high=255, shape=obs_shape, dtype=np.uint8)

    def observation(self, observation):
        transforms = T.Compose(
            [T.Resize(self.shape), T.Normalize(0, 255)]
        )
        observation = transforms(observation).squeeze(0) # GrayScale入力ならsqueeze(0)で次元を減らしている．
        return observation
  
# https://github.com/zakopuro/RL_mario

# CustomRewardAndDoneラッパー
class CustomRewardAndDoneEnv(gym.Wrapper):
    # 初期化
    def __init__(self, env, skip):
        super(CustomRewardAndDoneEnv, self).__init__(env)
        self._skip = skip
        self._cur_x = 0.0
        self._max_x = 0.0

    # リセット
    def reset(self, **kwargs):
        self._cur_x = 0.0
        return self.env.reset(**kwargs)

    # ステップ
    def step(self, action):
        total_reward = 0.0
        done = False
        
        for i in range(self._skip):
            # 各フレームごとの報酬はn番目のフレームに集約
            # 報酬を蓄積し、同じ行動を繰り返す
            state, reward, done, info = self.env.step(action)
            total_reward += reward
            if done:
                break
        
        # 報酬の変更
        if info['flag_get']:
            print("GOAL")
            total_reward += 100
            
        if info['x_pos'] >= self._max_x:
            self._max_x = info['x_pos']
            total_reward += 10
            
        if (info['x_pos'] < self._max_x) & (info['x_pos'] - self._max_x > -100):
            total_reward += 5
                
        if info['x_pos'] > self._cur_x:
            total_reward += 10

        elif info['x_pos'] == self._cur_x:
            total_reward -= 2
            
        else:
            total_reward -= 4

        self._cur_x = info['x_pos']

        total_reward -= 30 * (info['life'] - 1) # if info['life'] < 1:  total_reward -= 30

        if info['life'] == 1:
            done = True
            
        total_reward *= 0.2

        return state, total_reward, done, info

# Wrapper
# 4つの連続したグレースケールのフレームを重ね合わせたものになる
# マリオが行動を取るたびに環境は状態を返す
# サイズ[4, 84, 84]の3次元配列

#-----------------------------------------------------
#-----------------------------------------------------


# マリオは経験を一時的に記憶

class Mario:
    def __init__(self, state_dim, action_dim):
        self.state_dim = state_dim
        self.action_dim = action_dim

        self.use_cuda = torch.cuda.is_available()
        if self.use_cuda:
            self.net = self.net.to(device="cuda")

        # 最適な行動を予測するマリオ用のDNN
        self.net = MarioNet(self.state_dim, self.action_dim).float()

    def act(self, state):
        """
        ε-greedy法で行動を選択

        Inputs:
            state(LazyFrame):現在の状態における一つの観測オブジェクト(state_dim)次元
        Outputs:
            action_idx (int): 整数値
        """
        # 探索（EXPLORE）
        if np.random.rand() < self.exploration_rate:
            action_idx = np.random.randint(self.action_dim)

        # 活用（EXPLOIT）
        else:
            state = state.__array__()  # ndarray.__array__() コピー作成
            if self.use_cuda:
                state = torch.tensor(state).cuda()
            else:
                state = torch.tensor(state)
            state = state.unsqueeze(0)
            action_values = self.net(state, model="online") # actionを選ぶ
            action_idx = torch.argmax(action_values, axis=1).item()

        # exploration_rate減衰
        self.exploration_rate *= self.exploration_rate_decay
        self.exploration_rate = max(self.exploration_rate_min, self.exploration_rate)

        # ステップ+1
        self.curr_step += 1
        return action_idx

#-----------------------------------

class Mario(Mario):
    
    def cache(self, state, next_state, action, reward, done):
        """
        経験をself.memory (replay buffer)に保存

        Inputs:
            state (LazyFrame),
            next_state (LazyFrame),
            action (int),
            reward (float),
            done(bool))
        """
        state = state.__array__()
        next_state = next_state.__array__()

        if self.use_cuda:
            state = torch.tensor(state).cuda()
            next_state = torch.tensor(next_state).cuda()
            action = torch.tensor([action]).cuda()
            reward = torch.tensor([reward]).cuda()
            done = torch.tensor([done]).cuda()
        else:
            state = torch.tensor(state)
            next_state = torch.tensor(next_state)
            action = torch.tensor([action])
            reward = torch.tensor([reward])
            done = torch.tensor([done])

        self.memory.append((state, next_state, action, reward, done,))

    def recall(self):
        """
        メモリから経験のバッチを取得します
        """
        batch = random.sample(self.memory, self.batch_size)
        state, next_state, action, reward, done = map(torch.stack, zip(*batch)) 
        return state, next_state, action.squeeze(), reward.squeeze(), done.squeeze()
    
#-----------------------------------------------------

class MarioNet(nn.Module):

    def __init__(self, input_dim, output_dim):
        super().__init__()
        c, h, w = input_dim

        if h != 84:
            raise ValueError(f"Expecting input height: 84, got: {h}") # 例外発生
        if w != 84:
            raise ValueError(f"Expecting input width: 84, got: {w}")

        self.online = nn.Sequential(
            nn.Conv2d(in_channels=c, out_channels=32, kernel_size=8, stride=4),
            nn.ReLU(),
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=4, stride=2),
            nn.ReLU(),
            nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, stride=1),
            nn.ReLU(),
            nn.Flatten(), # 平坦化
            nn.Linear(3136, 512),
            nn.ReLU(),
            nn.Linear(512, output_dim),
        )

        self.target = copy.deepcopy(self.online)  # 参照ではなく完全コピー

        # Q_target パラメータ固定
        for p in self.target.parameters():
            p.requires_grad = False

    def forward(self, input, model):
        if model == "online":
            return self.online(input)
        elif model == "target":
            return self.target(input)
        
#---------------------------------------------------

class Mario(Mario):
       
    def td_estimate(self, state, action):
        current_Q = self.net(state, model="online")[
            np.arange(0, self.batch_size), action
        ]  # Q_online(s,a)
        return current_Q

    @torch.no_grad()
    def td_target(self, reward, next_state, done):
        next_state_Q = self.net(next_state, model="online")
        best_action = torch.argmax(next_state_Q, axis=1)
        next_Q = self.net(next_state, model="target")[
            np.arange(0, self.batch_size), best_action
        ]
        return (reward + (1 - done.float()) * self.gamma * next_Q).float()

#-----------------------------------------------------

class Mario(Mario):

    def update_Q_online(self, td_estimate, td_target):
        loss = self.loss_fn(td_estimate, td_target)
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()
        return loss.item()

    def sync_Q_target(self):
        self.net.target.load_state_dict(self.net.online.state_dict())

#-----------------------------------------------------

class Mario(Mario):

    def learn(self):
        if self.curr_step % self.sync_every == 0:
            self.sync_Q_target()

        if self.curr_step < self.burnin: # 初期は学習しない
            return None, None

        if self.curr_step % self.learn_every != 0:
            return None, None
        
        # メモリからサンプリング
        state, next_state, action, reward, done = self.recall()

        # TD Estimate取得
        td_est = self.td_estimate(state, action)

        # TD Target取得
        td_tgt = self.td_target(reward, next_state, done)

        # 損失をQ_onlineに逆伝播
        loss = self.update_Q_online(td_est, td_tgt)

        return (td_est.mean().item(), loss)

#-----------------------------------------------------
#-----------------------------------------------------




# ログ保存
import numpy as np
import time, datetime
import matplotlib.pyplot as plt


class MetricLogger:
    def __init__(self):

        # 指標の履歴
        self.ep_rewards = []
        self.ep_lengths = []
        self.ep_avg_losses = []
        self.ep_avg_qs = []

        # record()が呼び出されるたびに追加される移動平均
        self.moving_avg_ep_rewards = []
        self.moving_avg_ep_lengths = []
        self.moving_avg_ep_avg_losses = []
        self.moving_avg_ep_avg_qs = []
        self.ave_epnum = []

        # 現在のエピソードの指標
        self.init_episode()
        

    def log_step(self, reward, loss, q):
        self.curr_ep_reward += reward
        self.curr_ep_length += 1
        if loss:
            self.curr_ep_loss += loss
            self.curr_ep_q += q
            self.curr_ep_loss_length += 1
        return self.curr_ep_reward

    def log_episode(self):
        "エピソード終了時の記録"
        self.ep_rewards.append(self.curr_ep_reward)
        self.ep_lengths.append(self.curr_ep_length)
        if self.curr_ep_loss_length == 0:
            ep_avg_loss = 0
            ep_avg_q = 0
        else:
            ep_avg_loss = np.round(self.curr_ep_loss / self.curr_ep_loss_length, 5)
            ep_avg_q = np.round(self.curr_ep_q / self.curr_ep_loss_length, 5)
        self.ep_avg_losses.append(ep_avg_loss)
        self.ep_avg_qs.append(ep_avg_q)

        self.init_episode()

    def init_episode(self):
        self.curr_ep_reward = 0.0
        self.curr_ep_length = 0
        self.curr_ep_loss = 0.0
        self.curr_ep_q = 0.0
        self.curr_ep_loss_length = 0

    def record(self, episode, epsilon, step):
        mean_ep_reward = np.round(np.mean(self.ep_rewards[-100:]), 3)
        mean_ep_length = np.round(np.mean(self.ep_lengths[-100:]), 3)
        mean_ep_loss = np.round(np.mean(self.ep_avg_losses[-100:]), 3)
        mean_ep_q = np.round(np.mean(self.ep_avg_qs[-100:]), 3)
        self.moving_avg_ep_rewards.append(mean_ep_reward)
        self.moving_avg_ep_lengths.append(mean_ep_length)
        self.moving_avg_ep_avg_losses.append(mean_ep_loss)
        self.moving_avg_ep_avg_qs.append(mean_ep_q)
        self.ave_epnum.append(episode)  # 追加

        print(
            f"Episode {episode} - "
            f"Step {step} - "
            f"Epsilon {epsilon:.4f} - " # 小数点4桁まで
            f"Mean Reward {mean_ep_reward} - "
            f"Mean Length {mean_ep_length} - "
            f"Mean Loss {mean_ep_loss} - "
            f"Mean Q Value {mean_ep_q} - "
        )

    def plot_graph(self):
        plt.plot(self.ave_epnum,  self.moving_avg_ep_rewards, label='rewards')
        plt.plot(self.ave_epnum,  self.moving_avg_ep_lengths, label='length')
        plt.title('Learning process')
        plt.xlabel('Episodes') 
        plt.legend()
        
#-----------------------------------------------------       
# 設定値
        
class Mario(Mario):
    def __init__(self, state_dim, action_dim, setting):
        super().__init__(state_dim, action_dim)
        
        self.exploration_rate = setting['EXPLORATION_RATE']
        self.exploration_rate_decay = setting['EXPLORATION_RATE_DECAY']
        self.exploration_rate_min = setting['EXPLORATION_RATE_MIN']

        self.gamma = setting['GAMMA']  # 0.9

        self.memory = setting['MEMORY'] #maxlen=100000   # dequeは先頭末尾のアクセスが速いリスト
        self.batch_size = setting['BATCH_SIZE']
        self.burnin = setting['BURNIN'] # 経験を訓練させるために最低限必要なステップ数 (1e3)
        self.learn_every = setting['LEARN_EVERY']  # Q_onlineを更新するタイミングを示すステップ数 (3)
        self.sync_every = setting['SYNC_EVERY']  # Q_target & Q_onlineを同期させるタイミングを示すステップ数 (1e3)
        
        self.curr_step = 0
        self.optimizer = torch.optim.Adam(self.net.parameters(), lr=setting['LERNING_RATE']) # (lr=0.0001)
        self.loss_fn = torch.nn.SmoothL1Loss()

# %%
def set_my(env):
    env.reset()
    env = JoypadSpace(env, SIMPLE_MOVEMENT)
    env = GrayScaleObservation(env)
    env = ResizeObservation(env, shape=84)
    # 連続したフレームを1つにまとめ、それを学習モデルに入力
    env = FrameStack(env, num_stack=4)
    env = CustomRewardAndDoneEnv(env, skip=12) # 報酬とエピソード完了の変更

    return env

# %%
env = gym_super_mario_bros.make("SuperMarioBros-3-4-v3")
env = set_my(env)

#~~~~~~~ 設定値 ~~~~~~~
setting = dict(
    EXPLORATION_RATE = 1,
    EXPLORATION_RATE_DECAY = 0.9999555,
    EXPLORATION_RATE_MIN = 0.075,

    GAMMA = 0.9,  # 0.9

    MEMORY = deque(maxlen=10000), # maxlen=100000   # dequeは先頭末尾のアクセスが速いリスト
            # maxlen が大きいと，"CUDA out of memory"が出る．GPUメモリサイズは状況で変化するので調整が必要．
            # maxlenを設定した場合、dequeが満杯で要素を追加すると逆側の要素が捨てられる
    BATCH_SIZE = 32,
    LERNING_RATE = 0.0001,

    BURNIN = 1e3, # 経験を訓練させるために最低限必要なステップ数 (1e3)
    LEARN_EVERY = 3,  # Q_onlineを更新するタイミングを示すステップ数 (3)
    SYNC_EVERY = 1e3,  # Q_target & Q_onlineを同期させるタイミングを示すステップ数 (1e3)
)

hours = 10 # 何時間学習するか
REC_EP = 100 # 何episodeごとに出力するか

#~~~~~~~~~~~~~~

seconds = 3600*hours # 秒に変換
gone_time = 0 # 経過時間
start = int(time.time()) # 計測開始

e = 0 # episode数 mean_rewardを計算する
max_reward = 0 # 最大報酬
max_curr_x = 0 # 最長距離
curr_ep_reward = 0 # 現在のエピソードの報酬


print(datetime.datetime.now().strftime("%T"),end="")
print(f" + {int(hours)} 時間後に終了")

mario = Mario(state_dim=(4, 84, 84), action_dim=env.action_space.n, setting=setting)
logger = MetricLogger()

while True:
    
    e += 1
    state = env.reset()

    # ゲーム開始！
    while True:
        env.render() # ローカル環境で画面をウィンドウに表示

        # 現在の状態に対するエージェントの行動を決める
        action = mario.act(state)

        # エージェントが行動を実行
        next_state, reward, done, info = env.step(action)

        # 記憶
        mario.cache(state, next_state, action, reward, done)

        # 訓練
        q, loss = mario.learn()

        # ログ保存
        curr_ep_reward = logger.log_step(reward, loss, q)

        # 状態の更新
        state = next_state

        # ゲームが終了したかどうかを確認
        if done:
            break

    logger.log_episode()
    gone_time = int(time.time()) - start
    
    # 最大距離の時モデルをSAVE
    if info['x_pos'] > max_curr_x or  info['flag_get']:
        max_curr_x = info['x_pos']
        print(f"最長'距離'：x_position={max_curr_x:.1f}, episode：{e}, step：{mario.curr_step}")
        torch.save(mario.net.state_dict(), 'mario_param_new_best.pth')
        mario.net.load_state_dict(torch.load('mario_param_new_best.pth'))


    # 最大報酬の時モデルをSAVE
    if curr_ep_reward > max_reward:
        max_reward = curr_ep_reward
        print(f"最大'報酬'：reward={max_reward:.1f}, episode：{e}, step：{mario.curr_step}")
        torch.save(mario.net.state_dict(), 'mario_param_new_best.pth')
        mario.net.load_state_dict(torch.load('mario_param_new_best.pth'))

    # REC_EPごとに出力
    if e % REC_EP == 0:
        logger.record(episode=e, epsilon=mario.exploration_rate, step=mario.curr_step)

    # 1000EPごとに保存
    if e % 1000 == 0:
        torch.save(mario.net.state_dict(), 'mario_param_new.pth')
    
    # 経過時間超えたら終了
    if gone_time > seconds:
        env.close()
        break

torch.save(mario.net.state_dict(), 'mario_param_new.pth')
logger.plot_graph()
# Out:
# 19:28:35+10時間後に終了
# C:\Users\20044\anaconda3\envs\Pytorch\lib\site-packages\gym_super_mario_bros\smb_env.py:148: RuntimeWarning: overflow encountered in ubyte_scalars
#   return (self.ram[0x86] - self.ram[0x071c]) % 256
# 最長'距離'：x_position=275.0, episode：1, step：33
# 最長'距離'：x_position=771.0, episode：2, step：72
# 最大'報酬'：reward=38.0, episode：2, step：72
# 最長'距離'：x_position=825.0, episode：18, step：420
# Episode 100 - Step 2064 - Epsilon 0.9122 - Mean Reward -41.304 - Mean Length 20.64 - Mean Loss 0.726 - Mean Q Value -0.759 -
# 最長'距離'：x_position=835.0, episode：134, step：2799
# Episode 200 - Step 4155 - Epsilon 0.8312 - Mean Reward -44.466 - Mean Length 20.91 - Mean Loss 1.052 - Mean Q Value -3.086 -
# Episode 300 - Step 6009 - Epsilon 0.7654 - Mean Reward -31.986 - Mean Length 18.54 - Mean Loss 1.106 - Mean Q Value -3.946 -
# Episode 400 - Step 7854 - Epsilon 0.7050 - Mean Reward -34.758 - Mean Length 18.45 - Mean Loss 1.235 - Mean Q Value -4.442 -
# Episode 500 - Step 9654 - Epsilon 0.6508 - Mean Reward -29.622 - Mean Length 18.0 - Mean Loss 1.22 - Mean Q Value -4.77 -
# Episode 600 - Step 11290 - Epsilon 0.6051 - Mean Reward -23.158 - Mean Length 16.36 - Mean Loss 1.168 - Mean Q Value -4.885 -
# Episode 700 - Step 12773 - Epsilon 0.5664 - Mean Reward -13.642 - Mean Length 14.83 - Mean Loss 1.194 - Mean Q Value -4.534 -
# Episode 800 - Step 14327 - Epsilon 0.5286 - Mean Reward -17.522 - Mean Length 15.54 - Mean Loss 1.175 - Mean Q Value -3.797 -
# Episode 900 - Step 15813 - Epsilon 0.4948 - Mean Reward -14.052 - Mean Length 14.86 - Mean Loss 1.162 - Mean Q Value -3.219 -
# Episode 1000 - Step 17290 - Epsilon 0.4633 - Mean Reward -11.882 - Mean Length 14.77 - Mean Loss 1.112 - Mean Q Value -2.571 -
# Episode 1100 - Step 18801 - Epsilon 0.4332 - Mean Reward -13.12 - Mean Length 15.11 - Mean Loss 0.983 - Mean Q Value -1.895 -
# Episode 1200 - Step 20196 - Epsilon 0.4071 - Mean Reward -8.76 - Mean Length 13.95 - Mean Loss 0.888 - Mean Q Value -1.311 -
# 最長'距離'：x_position=836.0, episode：1220, step：20489
# Episode 1300 - Step 21676 - Epsilon 0.3811 - Mean Reward -8.984 - Mean Length 14.8 - Mean Loss 0.745 - Mean Q Value -0.57 -
# Episode 1400 - Step 23056 - Epsilon 0.3584 - Mean Reward -8.086 - Mean Length 13.8 - Mean Loss 0.732 - Mean Q Value -0.232 -
# Episode 1500 - Step 24437 - Epsilon 0.3371 - Mean Reward -8.234 - Mean Length 13.81 - Mean Loss 0.72 - Mean Q Value 0.004 -
# Episode 1600 - Step 25871 - Epsilon 0.3162 - Mean Reward -8.082 - Mean Length 14.34 - Mean Loss 0.646 - Mean Q Value 0.378 -
# Episode 1700 - Step 27303 - Epsilon 0.2967 - Mean Reward -9.528 - Mean Length 14.32 - Mean Loss 0.674 - Mean Q Value 0.359 -
# Episode 1800 - Step 28740 - Epsilon 0.2783 - Mean Reward -6.83 - Mean Length 14.37 - Mean Loss 0.631 - Mean Q Value 0.401 -
# Episode 1900 - Step 30099 - Epsilon 0.2620 - Mean Reward -4.776 - Mean Length 13.59 - Mean Loss 0.591 - Mean Q Value 0.391 -
# 最長'距離'：x_position=850.0, episode：1925, step：30505
# 最長'距離'：x_position=853.0, episode：1941, step：30800
# Episode 2000 - Step 31642 - Epsilon 0.2446 - Mean Reward -4.048 - Mean Length 15.43 - Mean Loss 0.602 - Mean Q Value 0.311 -
# Episode 2100 - Step 33128 - Epsilon 0.2290 - Mean Reward -4.506 - Mean Length 14.86 - Mean Loss 0.584 - Mean Q Value 0.357 -
# Episode 2200 - Step 34671 - Epsilon 0.2138 - Mean Reward -4.272 - Mean Length 15.43 - Mean Loss 0.614 - Mean Q Value 0.313 -
# Episode 2300 - Step 36191 - Epsilon 0.1998 - Mean Reward -2.394 - Mean Length 15.2 - Mean Loss 0.592 - Mean Q Value 0.378 -
# Episode 2400 - Step 37661 - Epsilon 0.1871 - Mean Reward -1.312 - Mean Length 14.7 - Mean Loss 0.612 - Mean Q Value 0.404 -
# Episode 2500 - Step 39168 - Epsilon 0.1750 - Mean Reward -3.058 - Mean Length 15.07 - Mean Loss 0.618 - Mean Q Value 0.623 -
# 最長'距離'：x_position=992.0, episode：2577, step：40311
# Episode 2600 - Step 40618 - Epsilon 0.1641 - Mean Reward -1.044 - Mean Length 14.5 - Mean Loss 0.653 - Mean Q Value 0.923 -
# Episode 2700 - Step 42269 - Epsilon 0.1524 - Mean Reward 2.632 - Mean Length 16.51 - Mean Loss 0.711 - Mean Q Value 1.349 -
# 最長'距離'：x_position=1266.0, episode：2777, step：43491
# 最大'報酬'：reward=71.2, episode：2777, step：43491
# Episode 2800 - Step 43835 - Epsilon 0.1422 - Mean Reward 2.828 - Mean Length 15.66 - Mean Loss 0.702 - Mean Q Value 1.723 -
# Episode 2900 - Step 45616 - Epsilon 0.1313 - Mean Reward 5.14 - Mean Length 17.81 - Mean Loss 0.746 - Mean Q Value 2.064 -
# 最長'距離'：x_position=1551.0, episode：2985, step：47134
# 最大'報酬'：reward=74.8, episode：2985, step：47134
# Episode 3000 - Step 47383 - Epsilon 0.1214 - Mean Reward 4.606 - Mean Length 17.67 - Mean Loss 0.699 - Mean Q Value 2.714 -
# Episode 3100 - Step 48937 - Epsilon 0.1133 - Mean Reward 2.824 - Mean Length 15.54 - Mean Loss 0.726 - Mean Q Value 3.198 -
# Episode 3200 - Step 50634 - Epsilon 0.1051 - Mean Reward 5.92 - Mean Length 16.97 - Mean Loss 0.659 - Mean Q Value 3.661 -
# Episode 3300 - Step 52413 - Epsilon 0.0971 - Mean Reward 5.824 - Mean Length 17.79 - Mean Loss 0.653 - Mean Q Value 4.257 -
# Episode 3400 - Step 54136 - Epsilon 0.0899 - Mean Reward 7.62 - Mean Length 17.23 - Mean Loss 0.625 - Mean Q Value 4.778 -
# Episode 3500 - Step 55608 - Epsilon 0.0842 - Mean Reward 2.714 - Mean Length 14.72 - Mean Loss 0.599 - Mean Q Value 5.037 -
# Episode 3600 - Step 57281 - Epsilon 0.0782 - Mean Reward 4.99 - Mean Length 16.73 - Mean Loss 0.613 - Mean Q Value 5.275 -
# Episode 3700 - Step 58994 - Epsilon 0.0750 - Mean Reward 5.0 - Mean Length 17.13 - Mean Loss 0.591 - Mean Q Value 5.421 -
# Episode 3800 - Step 60667 - Epsilon 0.0750 - Mean Reward 5.11 - Mean Length 16.73 - Mean Loss 0.61 - Mean Q Value 5.503 -
# Episode 3900 - Step 62576 - Epsilon 0.0750 - Mean Reward 11.022 - Mean Length 19.09 - Mean Loss 0.599 - Mean Q Value 5.354 -
# Episode 4000 - Step 64415 - Epsilon 0.0750 - Mean Reward 8.596 - Mean Length 18.39 - Mean Loss 0.548 - Mean Q Value 5.295 -
# Episode 4100 - Step 66226 - Epsilon 0.0750 - Mean Reward 8.106 - Mean Length 18.11 - Mean Loss 0.525 - Mean Q Value 5.663 -
# Episode 4200 - Step 68491 - Epsilon 0.0750 - Mean Reward 13.514 - Mean Length 22.65 - Mean Loss 0.517 - Mean Q Value 5.989 -
# 最長'距離'：x_position=1553.0, episode：4291, step：70829
# Episode 4300 - Step 71073 - Epsilon 0.0750 - Mean Reward 17.068 - Mean Length 25.82 - Mean Loss 0.504 - Mean Q Value 6.896 -
# Episode 4400 - Step 73760 - Epsilon 0.0750 - Mean Reward 19.938 - Mean Length 26.87 - Mean Loss 0.469 - Mean Q Value 7.842 -
# 最長'距離'：x_position=1576.0, episode：4439, step：74843
# Episode 4500 - Step 76605 - Epsilon 0.0750 - Mean Reward 19.962 - Mean Length 28.45 - Mean Loss 0.485 - Mean Q Value 8.414 -
# 最長'距離'：x_position=1646.0, episode：4532, step：77631
# 最大'報酬'：reward=85.0, episode：4532, step：77631
# Episode 4600 - Step 79800 - Epsilon 0.0750 - Mean Reward 25.284 - Mean Length 31.95 - Mean Loss 0.494 - Mean Q Value 8.654 -
# Episode 4700 - Step 82277 - Epsilon 0.0750 - Mean Reward 19.326 - Mean Length 24.77 - Mean Loss 0.572 - Mean Q Value 9.208 -
# 最長'距離'：x_position=1671.0, episode：4702, step：82357
# Episode 4800 - Step 84424 - Epsilon 0.0750 - Mean Reward 12.34 - Mean Length 21.47 - Mean Loss 0.587 - Mean Q Value 9.229 -
# 最大'報酬'：reward=85.0, episode：4856, step：86006
# Episode 4900 - Step 87354 - Epsilon 0.0750 - Mean Reward 21.348 - Mean Length 29.3 - Mean Loss 0.608 - Mean Q Value 9.559 -
# Episode 5000 - Step 90471 - Epsilon 0.0750 - Mean Reward 21.982 - Mean Length 31.17 - Mean Loss 0.7 - Mean Q Value 9.325 -
# 最長'距離'：x_position=1674.0, episode：5024, step：91235
# 最大'報酬'：reward=85.4, episode：5098, step：93957
# Episode 5100 - Step 94027 - Epsilon 0.0750 - Mean Reward 32.738 - Mean Length 35.56 - Mean Loss 0.709 - Mean Q Value 10.049 -
# 最大'報酬'：reward=86.0, episode：5126, step：95040
# Episode 5200 - Step 97628 - Epsilon 0.0750 - Mean Reward 33.83 - Mean Length 36.01 - Mean Loss 0.725 - Mean Q Value 10.537 -
# 最長'距離'：x_position=1736.0, episode：5237, step：99062
# 最大'報酬'：reward=99.0, episode：5237, step：99062
# Episode 5300 - Step 101479 - Epsilon 0.0750 - Mean Reward 21.376 - Mean Length 38.51 - Mean Loss 0.661 - Mean Q Value 11.022 -
# Episode 5400 - Step 105113 - Epsilon 0.0750 - Mean Reward 35.316 - Mean Length 36.34 - Mean Loss 0.647 - Mean Q Value 10.793 -
# Episode 5500 - Step 108960 - Epsilon 0.0750 - Mean Reward 38.808 - Mean Length 38.47 - Mean Loss 0.541 - Mean Q Value 11.166 -
# Episode 5600 - Step 112254 - Epsilon 0.0750 - Mean Reward 28.86 - Mean Length 32.94 - Mean Loss 0.496 - Mean Q Value 11.944 -
# 最長'距離'：x_position=1874.0, episode：5653, step：113858
# 最長'距離'：x_position=2168.0, episode：5697, step：115393
# Episode 5700 - Step 115524 - Epsilon 0.0750 - Mean Reward 25.834 - Mean Length 32.7 - Mean Loss 0.529 - Mean Q Value 12.081 -
# 最長'距離'：x_position=2202.0, episode：5737, step：116518
# 最長'距離'：x_position=2212.0, episode：5780, step：118066
# 最大'報酬'：reward=106.0, episode：5780, step：118066
# Episode 5800 - Step 118833 - Epsilon 0.0750 - Mean Reward 24.61 - Mean Length 33.09 - Mean Loss 0.672 - Mean Q Value 11.753 -
# Episode 5900 - Step 122313 - Epsilon 0.0750 - Mean Reward 30.884 - Mean Length 34.8 - Mean Loss 0.705 - Mean Q Value 11.766 -
# Episode 6000 - Step 125539 - Epsilon 0.0750 - Mean Reward 28.282 - Mean Length 32.26 - Mean Loss 0.677 - Mean Q Value 11.905 -
# Episode 6100 - Step 128815 - Epsilon 0.0750 - Mean Reward 30.262 - Mean Length 32.76 - Mean Loss 0.667 - Mean Q Value 11.993 -
# Episode 6200 - Step 132545 - Epsilon 0.0750 - Mean Reward 30.616 - Mean Length 37.3 - Mean Loss 0.657 - Mean Q Value 12.019 -
# Episode 6300 - Step 136491 - Epsilon 0.0750 - Mean Reward 38.25 - Mean Length 39.46 - Mean Loss 0.68 - Mean Q Value 12.127 -
# Episode 6400 - Step 140088 - Epsilon 0.0750 - Mean Reward 33.756 - Mean Length 35.97 - Mean Loss 0.645 - Mean Q Value 12.473 -
# Episode 6500 - Step 143871 - Epsilon 0.0750 - Mean Reward 37.016 - Mean Length 37.83 - Mean Loss 0.562 - Mean Q Value 12.959 -
# Episode 6600 - Step 148098 - Epsilon 0.0750 - Mean Reward 42.414 - Mean Length 42.27 - Mean Loss 0.549 - Mean Q Value 13.024 -
# 最大'報酬'：reward=111.0, episode：6613, step：148531
# Episode 6700 - Step 151986 - Epsilon 0.0750 - Mean Reward 37.396 - Mean Length 38.88 - Mean Loss 0.51 - Mean Q Value 12.863 -
# Episode 6800 - Step 155567 - Epsilon 0.0750 - Mean Reward 33.246 - Mean Length 35.81 - Mean Loss 0.54 - Mean Q Value 12.596 -
# Episode 6900 - Step 159177 - Epsilon 0.0750 - Mean Reward 34.574 - Mean Length 36.1 - Mean Loss 0.548 - Mean Q Value 12.574 -
# Episode 7000 - Step 163011 - Epsilon 0.0750 - Mean Reward 35.0 - Mean Length 38.34 - Mean Loss 0.547 - Mean Q Value 12.55 -
# Episode 7100 - Step 166793 - Epsilon 0.0750 - Mean Reward 37.782 - Mean Length 37.82 - Mean Loss 0.532 - Mean Q Value 12.673 -
# Episode 7200 - Step 170205 - Epsilon 0.0750 - Mean Reward 31.576 - Mean Length 34.12 - Mean Loss 0.497 - Mean Q Value 12.821 -
# Episode 7300 - Step 174015 - Epsilon 0.0750 - Mean Reward 38.226 - Mean Length 38.1 - Mean Loss 0.487 - Mean Q Value 12.69 -
# GOAL
# 最長'距離'：x_position=2259.0, episode：7324, step：174987
# 最大'報酬'：reward=135.0, episode：7324, step：174987
# Episode 7400 - Step 177506 - Epsilon 0.0750 - Mean Reward 34.186 - Mean Length 34.91 - Mean Loss 0.469 - Mean Q Value 12.917 -
# GOAL
# 最長'距離'：x_position=2259.0, episode：7489, step：181252
# Episode 7500 - Step 181585 - Epsilon 0.0750 - Mean Reward 39.416 - Mean Length 40.79 - Mean Loss 0.486 - Mean Q Value 12.841 -
# Episode 7600 - Step 185127 - Epsilon 0.0750 - Mean Reward 31.554 - Mean Length 35.42 - Mean Loss 0.501 - Mean Q Value 12.971 -
# Episode 7700 - Step 188791 - Epsilon 0.0750 - Mean Reward 36.442 - Mean Length 36.64 - Mean Loss 0.557 - Mean Q Value 13.138 -
# GOAL
# 最長'距離'：x_position=2264.0, episode：7781, step：191999
# 最大'報酬'：reward=147.0, episode：7781, step：191999
# Episode 7800 - Step 192574 - Epsilon 0.0750 - Mean Reward 38.362 - Mean Length 37.83 - Mean Loss 0.561 - Mean Q Value 13.099 -
# Episode 7900 - Step 196196 - Epsilon 0.0750 - Mean Reward 32.274 - Mean Length 36.22 - Mean Loss 0.594 - Mean Q Value 13.023 -
# Episode 8000 - Step 200186 - Epsilon 0.0750 - Mean Reward 27.886 - Mean Length 39.9 - Mean Loss 0.632 - Mean Q Value 12.759 -
# GOAL
# 最長'距離'：x_position=2257.0, episode：8093, step：203538
# GOAL
# 最長'距離'：x_position=2260.0, episode：8095, step：203650
# Episode 8100 - Step 203787 - Epsilon 0.0750 - Mean Reward 32.476 - Mean Length 36.01 - Mean Loss 0.731 - Mean Q Value 12.116 -
# Episode 8200 - Step 207407 - Epsilon 0.0750 - Mean Reward 30.052 - Mean Length 36.2 - Mean Loss 0.709 - Mean Q Value 12.287 -
# GOAL
# 最長'距離'：x_position=2265.0, episode：8240, step：208874
# 最大'報酬'：reward=147.2, episode：8240, step：208874
# Episode 8300 - Step 211018 - Epsilon 0.0750 - Mean Reward 35.038 - Mean Length 36.11 - Mean Loss 0.662 - Mean Q Value 12.643 -
# GOAL
# 最長'距離'：x_position=2262.0, episode：8337, step：212575
# Episode 8400 - Step 215118 - Epsilon 0.0750 - Mean Reward 40.638 - Mean Length 41.0 - Mean Loss 0.602 - Mean Q Value 13.051 -
# Episode 8500 - Step 219151 - Epsilon 0.0750 - Mean Reward 38.688 - Mean Length 40.33 - Mean Loss 0.556 - Mean Q Value 13.097 -
# Episode 8600 - Step 222762 - Epsilon 0.0750 - Mean Reward 33.79 - Mean Length 36.11 - Mean Loss 0.571 - Mean Q Value 13.18 -
# Episode 8700 - Step 226559 - Epsilon 0.0750 - Mean Reward 35.956 - Mean Length 37.97 - Mean Loss 0.556 - Mean Q Value 13.127 -
# GOAL
# 最長'距離'：x_position=2261.0, episode：8710, step：227062
# Episode 8800 - Step 230770 - Epsilon 0.0750 - Mean Reward 43.84 - Mean Length 42.11 - Mean Loss 0.512 - Mean Q Value 13.191 -
# Episode 8900 - Step 234515 - Epsilon 0.0750 - Mean Reward 37.856 - Mean Length 37.45 - Mean Loss 0.521 - Mean Q Value 13.383 -
# Episode 9000 - Step 238207 - Epsilon 0.0750 - Mean Reward 36.994 - Mean Length 36.92 - Mean Loss 0.521 - Mean Q Value 13.647 -
# Episode 9100 - Step 242227 - Epsilon 0.0750 - Mean Reward 35.806 - Mean Length 40.2 - Mean Loss 0.554 - Mean Q Value 13.775 -
# Episode 9200 - Step 246172 - Epsilon 0.0750 - Mean Reward 40.294 - Mean Length 39.45 - Mean Loss 0.577 - Mean Q Value 13.619 -
# Episode 9300 - Step 249891 - Epsilon 0.0750 - Mean Reward 33.17 - Mean Length 37.19 - Mean Loss 0.616 - Mean Q Value 13.285 -
# GOAL
# 最長'距離'：x_position=2254.0, episode：9316, step：250424
# Episode 9400 - Step 253200 - Epsilon 0.0750 - Mean Reward 29.248 - Mean Length 33.09 - Mean Loss 0.666 - Mean Q Value 13.481 -
# Episode 9500 - Step 256772 - Epsilon 0.0750 - Mean Reward 34.678 - Mean Length 35.72 - Mean Loss 0.638 - Mean Q Value 13.566 -
# Episode 9600 - Step 260354 - Epsilon 0.0750 - Mean Reward 35.108 - Mean Length 35.82 - Mean Loss 0.625 - Mean Q Value 13.758 -
# Episode 9700 - Step 263776 - Epsilon 0.0750 - Mean Reward 30.59 - Mean Length 34.22 - Mean Loss 0.605 - Mean Q Value 13.683 -
# GOAL
# 最長'距離'：x_position=2256.0, episode：9748, step：265426
# Episode 9800 - Step 267382 - Epsilon 0.0750 - Mean Reward 33.216 - Mean Length 36.06 - Mean Loss 0.633 - Mean Q Value 13.922 -
# GOAL
# 最長'距離'：x_position=2259.0, episode：9886, step：270371
# Episode 9900 - Step 270822 - Epsilon 0.0750 - Mean Reward 27.342 - Mean Length 34.4 - Mean Loss 0.67 - Mean Q Value 13.659 -
# GOAL
# 最長'距離'：x_position=2252.0, episode：9965, step：273031
# Episode 10000 - Step 274307 - Epsilon 0.0750 - Mean Reward 29.254 - Mean Length 34.85 - Mean Loss 0.703 - Mean Q Value 13.095 -
# Episode 10100 - Step 277585 - Epsilon 0.0750 - Mean Reward 31.318 - Mean Length 32.78 - Mean Loss 0.723 - Mean Q Value 12.911 -
# Episode 10200 - Step 281038 - Epsilon 0.0750 - Mean Reward 31.786 - Mean Length 34.53 - Mean Loss 0.712 - Mean Q Value 13.291 -
# Episode 10300 - Step 284525 - Epsilon 0.0750 - Mean Reward 33.32 - Mean Length 34.87 - Mean Loss 0.679 - Mean Q Value 13.217 -
# Episode 10400 - Step 287811 - Epsilon 0.0750 - Mean Reward 31.466 - Mean Length 32.86 - Mean Loss 0.658 - Mean Q Value 13.287 -
# GOAL
# 最長'距離'：x_position=2259.0, episode：10436, step：289243
# Episode 10500 - Step 291418 - Epsilon 0.0750 - Mean Reward 32.862 - Mean Length 36.07 - Mean Loss 0.573 - Mean Q Value 13.303 -
# Episode 10600 - Step 294451 - Epsilon 0.0750 - Mean Reward 25.232 - Mean Length 30.33 - Mean Loss 0.588 - Mean Q Value 13.239 -
# GOAL
# 最長'距離'：x_position=2254.0, episode：10697, step：297792
# Episode 10700 - Step 297884 - Epsilon 0.0750 - Mean Reward 33.102 - Mean Length 34.33 - Mean Loss 0.581 - Mean Q Value 13.307 -
# Episode 10800 - Step 301093 - Epsilon 0.0750 - Mean Reward 28.328 - Mean Length 32.09 - Mean Loss 0.608 - Mean Q Value 13.342 -
# GOAL
# 最長'距離'：x_position=2260.0, episode：10861, step：303033
# Episode 10900 - Step 304555 - Epsilon 0.0750 - Mean Reward 33.306 - Mean Length 34.62 - Mean Loss 0.596 - Mean Q Value 13.413 -
# Episode 11000 - Step 308355 - Epsilon 0.0750 - Mean Reward 37.12 - Mean Length 38.0 - Mean Loss 0.573 - Mean Q Value 13.295 -
# GOAL
# 最長'距離'：x_position=2256.0, episode：11053, step：310028
# Episode 11100 - Step 311499 - Epsilon 0.0750 - Mean Reward 29.29 - Mean Length 31.44 - Mean Loss 0.536 - Mean Q Value 13.112 -
# GOAL
# 最長'距離'：x_position=2262.0, episode：11172, step：314323
# Episode 11200 - Step 315095 - Epsilon 0.0750 - Mean Reward 33.482 - Mean Length 35.96 - Mean Loss 0.564 - Mean Q Value 12.737 -
# GOAL
# 最長'距離'：x_position=2261.0, episode：11268, step：318042
# Episode 11300 - Step 319337 - Epsilon 0.0750 - Mean Reward 45.132 - Mean Length 42.42 - Mean Loss 0.539 - Mean Q Value 12.958 -
# Episode 11400 - Step 323261 - Epsilon 0.0750 - Mean Reward 39.906 - Mean Length 39.24 - Mean Loss 0.496 - Mean Q Value 13.206 -
# GOAL
# 最長'距離'：x_position=2251.0, episode：11456, step：325398
# GOAL
# 最長'距離'：x_position=2252.0, episode：11498, step：326985
# Episode 11500 - Step 327011 - Epsilon 0.0750 - Mean Reward 31.134 - Mean Length 37.5 - Mean Loss 0.498 - Mean Q Value 13.26 -
# GOAL
# 最長'距離'：x_position=2259.0, episode：11529, step：328077
# Episode 11600 - Step 330762 - Epsilon 0.0750 - Mean Reward 37.39 - Mean Length 37.51 - Mean Loss 0.521 - Mean Q Value 13.227 -
# GOAL
# 最長'距離'：x_position=2255.0, episode：11617, step：331432
# Episode 11700 - Step 334438 - Epsilon 0.0750 - Mean Reward 33.042 - Mean Length 36.76 - Mean Loss 0.612 - Mean Q Value 13.113 -
# Episode 11800 - Step 338807 - Epsilon 0.0750 - Mean Reward 44.69 - Mean Length 43.69 - Mean Loss 0.618 - Mean Q Value 13.023 -
# Episode 11900 - Step 342578 - Epsilon 0.0750 - Mean Reward 35.222 - Mean Length 37.71 - Mean Loss 0.587 - Mean Q Value 13.131 -
# Episode 12000 - Step 346338 - Epsilon 0.0750 - Mean Reward 37.61 - Mean Length 37.6 - Mean Loss 0.545 - Mean Q Value 13.488 -
# Episode 12100 - Step 350356 - Epsilon 0.0750 - Mean Reward 39.9 - Mean Length 40.18 - Mean Loss 0.491 - Mean Q Value 13.453 -
# Episode 12200 - Step 354031 - Epsilon 0.0750 - Mean Reward 33.078 - Mean Length 36.75 - Mean Loss 0.517 - Mean Q Value 13.357 -
# GOAL
# 最長'距離'：x_position=2263.0, episode：12273, step：356561
# Episode 12300 - Step 357506 - Epsilon 0.0750 - Mean Reward 32.296 - Mean Length 34.75 - Mean Loss 0.556 - Mean Q Value 13.326 -
# GOAL
# 最長'距離'：x_position=2259.0, episode：12307, step：357781
# Episode 12400 - Step 361459 - Epsilon 0.0750 - Mean Reward 40.152 - Mean Length 39.53 - Mean Loss 0.595 - Mean Q Value 13.114 -
# Episode 12500 - Step 365479 - Epsilon 0.0750 - Mean Reward 42.986 - Mean Length 40.2 - Mean Loss 0.555 - Mean Q Value 13.258 -
# GOAL
# 最長'距離'：x_position=2255.0, episode：12526, step：366541
# Episode 12600 - Step 369144 - Epsilon 0.0750 - Mean Reward 35.756 - Mean Length 36.65 - Mean Loss 0.495 - Mean Q Value 13.363 -
# GOAL
# 最長'距離'：x_position=2259.0, episode：12658, step：371400
# Episode 12700 - Step 372942 - Epsilon 0.0750 - Mean Reward 35.376 - Mean Length 37.98 - Mean Loss 0.492 - Mean Q Value 13.418 -
# Episode 12800 - Step 376319 - Epsilon 0.0750 - Mean Reward 28.758 - Mean Length 33.77 - Mean Loss 0.528 - Mean Q Value 13.284 -
# Episode 12900 - Step 379550 - Epsilon 0.0750 - Mean Reward 27.122 - Mean Length 32.31 - Mean Loss 0.623 - Mean Q Value 13.224 -
# Episode 13000 - Step 383471 - Epsilon 0.0750 - Mean Reward 39.718 - Mean Length 39.21 - Mean Loss 0.561 - Mean Q Value 12.963 -
# Episode 13100 - Step 387155 - Epsilon 0.0750 - Mean Reward 33.484 - Mean Length 36.84 - Mean Loss 0.549 - Mean Q Value 12.907 -
# Episode 13200 - Step 390879 - Epsilon 0.0750 - Mean Reward 32.208 - Mean Length 37.24 - Mean Loss 0.528 - Mean Q Value 12.882 -
# Episode 13300 - Step 394899 - Epsilon 0.0750 - Mean Reward 40.25 - Mean Length 40.2 - Mean Loss 0.549 - Mean Q Value 12.801 -
# GOAL
# 最長'距離'：x_position=2259.0, episode：13309, step：395226
# Episode 13400 - Step 398363 - Epsilon 0.0750 - Mean Reward 30.66 - Mean Length 34.64 - Mean Loss 0.541 - Mean Q Value 13.042 -
# GOAL
# 最長'距離'：x_position=2255.0, episode：13446, step：400317
# Episode 13500 - Step 402374 - Epsilon 0.0750 - Mean Reward 39.452 - Mean Length 40.11 - Mean Loss 0.566 - Mean Q Value 12.968 -
# Episode 13600 - Step 406165 - Epsilon 0.0750 - Mean Reward 37.638 - Mean Length 37.91 - Mean Loss 0.557 - Mean Q Value 12.922 -
# GOAL
# 最長'距離'：x_position=2260.0, episode：13619, step：406966
# GOAL
# 最長'距離'：x_position=2260.0, episode：13676, step：409140
# Episode 13700 - Step 409808 - Epsilon 0.0750 - Mean Reward 33.106 - Mean Length 36.43 - Mean Loss 0.51 - Mean Q Value 13.245 -
# GOAL
# 最長'距離'：x_position=2259.0, episode：13759, step：412223
# Episode 13800 - Step 413944 - Epsilon 0.0750 - Mean Reward 44.486 - Mean Length 41.36 - Mean Loss 0.496 - Mean Q Value 13.26 -
# Episode 13900 - Step 418035 - Epsilon 0.0750 - Mean Reward 40.53 - Mean Length 40.91 - Mean Loss 0.52 - Mean Q Value 13.378 -
# GOAL
# 最長'距離'：x_position=2261.0, episode：13902, step：418131
# GOAL
# 最長'距離'：x_position=2261.0, episode：13996, step：422121
# Episode 14000 - Step 422270 - Epsilon 0.0750 - Mean Reward 41.97 - Mean Length 42.35 - Mean Loss 0.49 - Mean Q Value 13.562 -
# Episode 14100 - Step 426537 - Epsilon 0.0750 - Mean Reward 44.68 - Mean Length 42.67 - Mean Loss 0.45 - Mean Q Value 13.407 -
# GOAL
# 最長'距離'：x_position=2259.0, episode：14156, step：428869

# %%
# 動画作成準備
# 必要に応じて 
#  pip install ipywidgets
#  conda install -c conda-forge ffmpeg
from IPython.display import HTML
from IPython import display
from matplotlib import animation
from importlib import reload
# %matplotlib inline

def display_frames_as_gif(frames):
    reload(plt)
    fig = plt.figure(figsize=(frames[0].shape[1]/72.0, frames[0].shape[0]/72.0),dpi=72)
    patch = plt.imshow(frames[0])
    plt.axis('off')
    
    def animate(i):
        img = patch.set_data(frames[i])
        return img
        
    anim = animation.FuncAnimation(plt.gcf(), animate, frames=len(frames), interval=40)
    
    # anim.save('movie_mario.mp4')  # ビデオファイルをsaveしたい場合
    return HTML(anim.to_jshtml())

# %%
env = gym_super_mario_bros.make("SuperMarioBros-3-4-v3")
env = set_my(env)

matplotlib.rcParams['animation.embed_limit'] = 2**128
# # Saveしたパラメータの読み込み

#~~~~~~~ 設定値 ~~~~~~~
setting = dict(
    EXPLORATION_RATE = 1,
    EXPLORATION_RATE_DECAY = 0.01,
    EXPLORATION_RATE_MIN = 0.075,

    GAMMA = 0.9,  # 0.9

    MEMORY = deque(maxlen=10000), # maxlen=100000   # dequeは先頭末尾のアクセスが速いリスト
            # maxlen が大きいと，"CUDA out of memory"が出る．GPUメモリサイズは状況で変化するので調整が必要．
            # maxlenを設定した場合、dequeが満杯で要素を追加すると逆側の要素が捨てられる
    BATCH_SIZE = 32,
    LERNING_RATE = 0.0001,

    BURNIN = 1e3, # 経験を訓練させるために最低限必要なステップ数 (1e3)
    LEARN_EVERY = 3,  # Q_onlineを更新するタイミングを示すステップ数 (3)
    SYNC_EVERY = 1e3,  # Q_target & Q_onlineを同期させるタイミングを示すステップ数 (1e3)
)

hours = 0.01 # 何時間学習するか
REC_EP = 1 # 何episodeごとに出力するか

#~~~~~~~~~~~~~~

seconds = 3600*hours # 秒に変換
gone_time = 0 # 経過時間
start = int(time.time()) # 計測開始

e = 0 # episode数 mean_rewardを計算する
max_reward = 0 # 最大報酬
max_curr_x = 0 # 最長距離
curr_ep_reward = 0 # 現在のエピソードの報酬
frames_best = []

print(datetime.datetime.now().strftime("%T"),end="")
print(f" + {int(hours)} 時間後に終了")

mario = Mario(state_dim=(4, 84, 84), action_dim=env.action_space.n, setting=setting)
mario.net.load_state_dict(torch.load('mario_param_new_best.pth'))

logger = MetricLogger()

while True:
    frames = [] 
    e += 1
    state = env.reset()

    # ゲーム開始！
    while True:
        frames.append(copy.deepcopy(env.render(mode = 'rgb_array')))

        env.render() # ローカル環境で画面をウィンドウに表示

        # 現在の状態に対するエージェントの行動を決める
        action = mario.act(state)

        # エージェントが行動を実行
        next_state, reward, done, info = env.step(action)

        # 記憶
        mario.cache(state, next_state, action, reward, done)

        # ログ保存
        curr_ep_reward = logger.log_step(reward, loss, q)

        # 状態の更新
        state = next_state

        # ゲームが終了したかどうかを確認
        if done:
            break

    logger.log_episode()
    gone_time = int(time.time()) - start
    
    # 最大距離の時モデルをSAVE
    if info['x_pos'] > max_curr_x or  info['flag_get']:
        max_curr_x = info['x_pos']
        print(f"最長'距離'：x_position={max_curr_x:.1f}, episode：{e}, step：{mario.curr_step}")
        frames_best = copy.deepcopy(frames)

    # 最大報酬の時モデルをSAVE
    if curr_ep_reward > max_reward:
        max_reward = curr_ep_reward
        print(f"最大'報酬'：reward={max_reward:.1f}, episode：{e}, step：{mario.curr_step}")
        frames_best = copy.deepcopy(frames)

    # REC_EPごとに出力
    if e % REC_EP == 0:
        logger.record(episode=e, epsilon=mario.exploration_rate, step=mario.curr_step)
    
    if (time.time() - start) > seconds or info["flag_get"]:
        break
    else:
        frames = []
        
env.close()
html = display_frames_as_gif(frames_best) ## *** 描画結果をHTMLオブジェクトで取得する  ***
html ## *** IPython系でインラインHTML表示 ***
# torch.save(mario.net.state_dict(), 'mario_param_new.pth')
# logger.plot_graph()
# Out:
# 11:58:25 + 0 時間後に終了
# C:\Users\20044\anaconda3\envs\Pytorch\lib\site-packages\gym_super_mario_bros\smb_env.py:148: RuntimeWarning: overflow encountered in ubyte_scalars
#   return (self.ram[0x86] - self.ram[0x071c]) % 256
# 最長'距離'：x_position=1640.0, episode：1, step：59
# 最大'報酬'：reward=193.0, episode：1, step：59
# Episode 1 - Step 59 - Epsilon 0.0750 - Mean Reward 193.0 - Mean Length 59.0 - Mean Loss 1.156 - Mean Q Value -1.309 -
# Episode 2 - Step 73 - Epsilon 0.0750 - Mean Reward 97.8 - Mean Length 36.5 - Mean Loss 1.156 - Mean Q Value -1.309 -
# Episode 3 - Step 130 - Epsilon 0.0750 - Mean Reward 90.0 - Mean Length 43.333 - Mean Loss 1.156 - Mean Q Value -1.309 -
# Episode 4 - Step 185 - Epsilon 0.0750 - Mean Reward 79.3 - Mean Length 46.25 - Mean Loss 1.156 - Mean Q Value -1.309 -
# Episode 5 - Step 238 - Epsilon 0.0750 - Mean Reward 75.44 - Mean Length 47.6 - Mean Loss 1.156 - Mean Q Value -1.309 -
# 最長'距離'：x_position=1734.0, episode：6, step：298
# Episode 6 - Step 298 - Epsilon 0.0750 - Mean Reward 79.6 - Mean Length 49.667 - Mean Loss 1.156 - Mean Q Value -1.309 -
# 最長'距離'：x_position=2191.0, episode：7, step：374
# Episode 7 - Step 374 - Epsilon 0.0750 - Mean Reward 89.829 - Mean Length 53.429 - Mean Loss 1.156 - Mean Q Value -1.309 -
# Episode 8 - Step 396 - Epsilon 0.0750 - Mean Reward 78.525 - Mean Length 49.5 - Mean Loss 1.156 - Mean Q Value -1.309 -
# Episode 9 - Step 437 - Epsilon 0.0750 - Mean Reward 73.422 - Mean Length 48.556 - Mean Loss 1.156 - Mean Q Value -1.309 -
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img34e0788055db4d1bb803d9db24badc6b">
#   <div class="anim-controls">
#     <input id="_anim_slider34e0788055db4d1bb803d9db24badc6b" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim34e0788055db4d1bb803d9db24badc6b.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim34e0788055db4d1bb803d9db24badc6b.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim34e0788055db4d1bb803d9db24badc6b.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim34e0788055db4d1bb803d9db24badc6b.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim34e0788055db4d1bb803d9db24badc6b.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim34e0788055db4d1bb803d9db24badc6b.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim34e0788055db4d1bb803d9db24badc6b.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim34e0788055db4d1bb803d9db24badc6b.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim34e0788055db4d1bb803d9db24badc6b.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim34e0788055db4d1bb803d9db24badc6b.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select34e0788055db4d1bb803d9db24badc6b"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_34e0788055db4d1bb803d9db24badc6b"
#              >
#       <label for="_anim_radio1_34e0788055db4d1bb803d9db24badc6b">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_34e0788055db4d1bb803d9db24badc6b"
#              checked>
#       <label for="_anim_radio2_34e0788055db4d1bb803d9db24badc6b">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_34e0788055db4d1bb803d9db24badc6b"
#              >
#       <label for="_anim_radio3_34e0788055db4d1bb803d9db24badc6b">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img34e0788055db4d1bb803d9db24badc6b";
#     var slider_id = "_anim_slider34e0788055db4d1bb803d9db24badc6b";
#     var loop_select_id = "_anim_loop_select34e0788055db4d1bb803d9db24badc6b";
#     var frames = new Array(76);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjUuMiwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy8qNh9FAAAACXBIWXMAAAsT\
# AAALEwEAmpwYAAAGD0lEQ
